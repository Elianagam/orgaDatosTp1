# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
auctions = pd.read_csv("data/auctions.csv.gzip", parse_dates=['date'])
auctions.head()
# Out:
#    auction_type_id              country                       date  \
# 0              NaN  6333597102633388268 2019-03-11 14:18:33.290763
# 1              NaN  6333597102633388268 2019-03-11 14:18:34.440157
# 2              NaN  6333597102633388268 2019-03-11 14:18:35.862360
# 3              NaN  6333597102633388268 2019-03-11 14:18:36.167163
# 4              NaN  6333597102633388268 2019-03-11 14:18:37.728590
#
#              device_id  platform  ref_type_id  source_id
# 0  6059599345986491085         1            1          0
# 1  1115994996230693426         1            1          0
# 2  7463856250762200923         1            1          0
# 3  7829815350267792040         1            1          0
# 4  1448534231953777480         1            1          0

# %%
#reduciendo el dataset
auctions = auctions.iloc[0:200000]

# %%
auctions.memory_usage()
# Out:
# Index                   80
# auction_type_id    1600000
# country            1600000
# date               1600000
# device_id          1600000
# platform           1600000
# ref_type_id        1600000
# source_id          1600000
# dtype: int64

# %%
auctions.dtypes
# Out:
# auction_type_id           float64
# country                     int64
# date               datetime64[ns]
# device_id                   int64
# platform                    int64
# ref_type_id                 int64
# source_id                   int64
# dtype: object

# %%
auctions.count()
# Out:
# auction_type_id         0
# country            200000
# date               200000
# device_id          200000
# platform           200000
# ref_type_id        200000
# source_id          200000
# dtype: int64

# %%
auctions = auctions.drop('auction_type_id', axis=1)

# %%
auctions.describe()
# Out:
#             country     device_id       platform    ref_type_id      source_id
# count  2.000000e+05  2.000000e+05  200000.000000  200000.000000  200000.000000
# mean   6.333597e+18  4.593268e+18       1.175075       2.050450       0.782710
# std    2.185529e+07  2.676375e+18       0.380032       2.280193       1.512804
# min    6.333597e+18  3.560846e+14       1.000000       1.000000       0.000000
# 25%    6.333597e+18  2.232225e+18       1.000000       1.000000       0.000000
# 50%    6.333597e+18  4.622451e+18       1.000000       1.000000       0.000000
# 75%    6.333597e+18  6.907992e+18       1.000000       1.000000       1.000000
# max    6.333597e+18  9.223171e+18       2.000000       7.000000       6.000000

# %%
auctions_corr = auctions.corr().abs().round(3)
plt.figure(figsize=(6, 6))
sns.heatmap(auctions_corr, annot=True);

# %%
auctions['country'].value_counts()
# Out:
# 6333597102633388268    200000
# Name: country, dtype: int64

# %%
auctions['platform'].value_counts()
# Out:
# 1    164985
# 2     35015
# Name: platform, dtype: int64

# %%
auctions['ref_type_id'].value_counts()
# Out:
# 1    164985
# 7     35015
# Name: ref_type_id, dtype: int64

# %%
auctions['source_id'].value_counts()
# Out:
# 0    130215
# 1     43884
# 5     18032
# 2      6179
# 6      1690
# Name: source_id, dtype: int64

# %%
auctions.loc[:,'platform'] = pd.Categorical(auctions['platform'])
auctions.loc[:,'ref_type_id'] = pd.Categorical(auctions['ref_type_id'])
auctions.loc[:,'source_id'] = pd.Categorical(auctions['source_id'])

# %%
auctions.describe()
# Out:
#             country     device_id
# count  2.000000e+05  2.000000e+05
# mean   6.333597e+18  4.593268e+18
# std    2.185529e+07  2.676375e+18
# min    6.333597e+18  3.560846e+14
# 25%    6.333597e+18  2.232225e+18
# 50%    6.333597e+18  4.622451e+18
# 75%    6.333597e+18  6.907992e+18
# max    6.333597e+18  9.223171e+18

# %%
auctions.memory_usage()
# Out:
# Index               80
# country        1600000
# date           1600000
# device_id      1600000
# platform        200096
# ref_type_id     200096
# source_id       200200
# dtype: int64

# %%
gb = auctions.groupby('device_id').size().nlargest(5)

# %%
top_auctions = auctions.loc[auctions['device_id'].isin(gb.keys())]

# %%
top_auctions['date'].max() - top_auctions['date'].min()
# Out:
# Timedelta('8 days 06:15:07.144339')

# %%
top_auctions.loc[:, 'date'] = top_auctions['date'].dt.date
# Out:
# D:\Program Files\Anaconda\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
top_auctions_ = top_auctions.groupby(['device_id', 'date']).size().to_frame().reset_index()
top_auctions_.set_index('device_id')
top_auctions_.columns = ['device_id', 'date', 'count']
top_auctions_
# Out:
#               device_id        date  count
# 0    633139769114048761  2019-03-05     11
# 1    633139769114048761  2019-03-07     87
# 2    633139769114048761  2019-03-08     74
# 3    633139769114048761  2019-03-09      6
# 4    633139769114048761  2019-03-11     12
# 5    633139769114048761  2019-03-12     93
# 6    633139769114048761  2019-03-13     98
# 7   5376802567578262905  2019-03-07      5
# 8   5376802567578262905  2019-03-08     14
# 9   5376802567578262905  2019-03-09      5
# 10  5376802567578262905  2019-03-10     20
# 11  5376802567578262905  2019-03-12     26
# 12  5376802567578262905  2019-03-13    107
# 13  6302840482782120473  2019-03-07    114
# 14  6302840482782120473  2019-03-08     92
# 15  6302840482782120473  2019-03-09      9
# 16  6302840482782120473  2019-03-12     94
# 17  6538458483957268825  2019-03-12     41
# 18  6538458483957268825  2019-03-13    141
# 19  7298861376107043945  2019-03-07     55
# 20  7298861376107043945  2019-03-08     23
# 21  7298861376107043945  2019-03-09     10
# 22  7298861376107043945  2019-03-10      2
# 23  7298861376107043945  2019-03-12     81
# 24  7298861376107043945  2019-03-13     12

# %%
fig, ax = plt.subplots()
for key, grp in top_auctions_.groupby(['device_id']):
    ax = grp.plot(ax=ax, kind='line', x='date', y='count', label=key, figsize=(20,8))
plt.title("Cantidad de subastas por día por los dispositivos que más subastas realizan",size=20)
ax.set_ylabel('Cantidad de subastas',size=15);
ax.set_xlabel('Día',size=15);
plt.show()

# %%
auctions['hour'] = auctions['date'].dt.hour

# %%
fig, ax = plt.subplots()
auctions.groupby('hour').size().plot(figsize=(10,5))
plt.title("Cantidad de subastas por hora del día", size=20)
ax.set_ylabel('Cantidad de subastas', size=15);
ax.set_xlabel('Hora del día', size=15);
plt.xticks(range(0,24,1));
plt.show()

# %%
fig, ax = plt.subplots()
gb = auctions.groupby(['platform'])
for key, grp in gb:
    grp.groupby('hour').size().plot(ax=ax, kind='line', label=key, figsize=(10,5))
plt.title("Cantidad de subastas por hora del día para cada plataforma", size=18)
plt.legend()
ax.set_ylabel('Cantidad de subastas', size=15);
ax.set_xlabel('Hora del día', size=15);
plt.xticks(range(0,24,1));
plt.show()

# %%
gb = auctions.groupby(['hour', 'platform']).size()
percentages = gb.groupby(level=[0]).apply(lambda x: x / x.sum()).reset_index()
percentages.columns = ['hour', 'platform', 'freq']
fig, ax = plt.subplots()
percentages.pivot_table(index='hour', columns='platform', values='freq').plot(ax=ax, kind='area', figsize=(10, 5))
plt.title('Proporción de subastas por plataforma para cada hora del día', size=18)
ax.set_ylabel('Proporción', size=15)
ax.set_xlabel('Hora del día', size=15)
plt.xticks(range(0,24,1));
plt.show()

# %% [markdown]
# **Tiempo promedio entre dos apariciones de un mismo dispositivo**

# %%
duplicate_auctions = auctions.groupby('device_id').filter(lambda x: len(x) > 1)
duplicate_auctions_ = duplicate_auctions.groupby('device_id').agg({'date': ['min', 'max'], 'device_id': 'size'}).reset_index()
duplicate_auctions_['mean_time'] = (duplicate_auctions_['date']['max'] - duplicate_auctions_['date']['min']) / duplicate_auctions_['device_id']['size']
duplicate_auctions_.columns = ['device_id', 'min_date', 'max_date', 'appearences', 'mean_time']
duplicate_auctions_['mean_time'].mean()
# Out:
# Timedelta('0 days 10:22:27.686378')

# %%
df = auctions.groupby('device_id').agg('size').reset_index()
df.columns = ['device_id', 'total_count']
df = pd.merge(df, auctions, on='device_id')
df

df2 = auctions.groupby(['device_id', 'source_id']).agg('size').reset_index()
df2.columns = ['device_id', 'source_id', 'single_count']
#df = df.groupby(['device_id', 'source_id']).agg({'single_count': 'count'}).reset_index()
#df
#df.groupby(['device_id', 'source_id'])
# Out:
#                   device_id  total_count              country  \
# 0           356084629798952            1  6333597102633388268
# 1           542666285694718            2  6333597102633388268
# 2           542666285694718            2  6333597102633388268
# 3           557498597278769            2  6333597102633388268
# 4           557498597278769            2  6333597102633388268
# 5           977705709646586            1  6333597102633388268
# 6          1178663993884805            2  6333597102633388268
# 7          1178663993884805            2  6333597102633388268
# 8          1245114284268118            3  6333597102633388268
# 9          1245114284268118            3  6333597102633388268
# 10         1245114284268118            3  6333597102633388268
# 11         1355652949840085           13  6333597102633388268
# 12         1355652949840085           13  6333597102633388268
# 13         1355652949840085           13  6333597102633388268
# 14         1355652949840085           13  6333597102633388268
# 15         1355652949840085           13  6333597102633388268
# 16         1355652949840085           13  6333597102633388268
# 17         1355652949840085           13  6333597102633388268
# 18         1355652949840085           13  6333597102633388268
# 19         1355652949840085           13  6333597102633388268
# 20         1355652949840085           13  6333597102633388268
# 21         1355652949840085           13  6333597102633388268
# 22         1355652949840085           13  6333597102633388268
# 23         1355652949840085           13  6333597102633388268
# 24         1360619548394952            3  6333597102633388268
# 25         1360619548394952            3  6333597102633388268
# 26         1360619548394952            3  6333597102633388268
# 27         1496749780481786            2  6333597102633388268
# 28         1496749780481786            2  6333597102633388268
# 29         1634988790779739            1  6333597102633388268
# ...                     ...          ...                  ...
# 199970  9222421543717736179            6  6333597102633388268
# 199971  9222421543717736179            6  6333597102633388268
# 199972  9222421543717736179            6  6333597102633388268
# 199973  9222457337246692634            3  6333597102633388268
# 199974  9222457337246692634            3  6333597102633388268
# 199975  9222457337246692634            3  6333597102633388268
# 199976  9222587923394718680            1  6333597102633388268
# 199977  9222917328677733151           21  6333597102633388268
# 199978  9222917328677733151           21  6333597102633388268
# 199979  9222917328677733151           21  6333597102633388268
# 199980  9222917328677733151           21  6333597102633388268
# 199981  9222917328677733151           21  6333597102633388268
# 199982  9222917328677733151           21  6333597102633388268
# 199983  9222917328677733151           21  6333597102633388268
# 199984  9222917328677733151           21  6333597102633388268
# 199985  9222917328677733151           21  6333597102633388268
# 199986  9222917328677733151           21  6333597102633388268
# 199987  9222917328677733151           21  6333597102633388268
# 199988  9222917328677733151           21  6333597102633388268
# 199989  9222917328677733151           21  6333597102633388268
# 199990  9222917328677733151           21  6333597102633388268
# 199991  9222917328677733151           21  6333597102633388268
# 199992  9222917328677733151           21  6333597102633388268
# 199993  9222917328677733151           21  6333597102633388268
# 199994  9222917328677733151           21  6333597102633388268
# 199995  9222917328677733151           21  6333597102633388268
# 199996  9222917328677733151           21  6333597102633388268
# 199997  9222917328677733151           21  6333597102633388268
# 199998  9223080948870532020            1  6333597102633388268
# 199999  9223170924238157866            1  6333597102633388268
#
#                              date platform ref_type_id source_id  hour
# 0      2019-03-08 22:27:20.952442        1           1         6    22
# 1      2019-03-07 03:55:57.562023        1           1         0     3
