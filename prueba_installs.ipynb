# %%
import pandas as pd
import numpy as np

# %%
installs = pd.read_csv('data/train_installs.csv.gzip')
#agregar dtype y diccionario ,dtype = {'created':'str', 'application_id':np.int8,}, parse_dates = ['created']

# %%
# languaje in iphone van a ser en ingles??

# %%
installs.dtypes
# Out:
# created                object
# application_id          int64
# ref_type                int64
# ref_hash                int64
# click_hash            float64
# attributed               bool
# implicit                 bool
# device_countrycode      int64
# device_brand          float64
# device_model          float64
# session_user_agent     object
# user_agent             object
# event_uuid             object
# kind                   object
# wifi                   object
# trans_id               object
# ip_address              int64
# device_language       float64
# dtype: object

# %%
installs.head().T
# Out:
#                                           0                        1  \
# created             2019-03-13 01:43:33.445  2019-03-13 04:58:35.078
# application_id                            0                        0
# ref_type                1891515180541284343      1891515180541284343
# ref_hash                8464844987297247076      3250564871270161533
# click_hash                              NaN                      NaN
# attributed                            False                    False
# implicit                              False                    False
# device_countrycode      6333597102633388268      6333597102633388268
# device_brand                    3.08306e+17              3.08306e+17
# device_model                    4.44525e+18              4.44525e+18
# session_user_agent                      NaN                      NaN
# user_agent                              NaN                      NaN
# event_uuid                              NaN                      NaN
# kind                                    NaN                      NaN
# wifi                                    NaN                      NaN
# trans_id                                NaN                      NaN
# ip_address              5529284367937637301      6098022721363533304
# device_language                         NaN                      NaN
#
#                                                        2  \
# created                          2019-03-13 04:20:57.666
# application_id                                         0
# ref_type                             1891515180541284343
# ref_hash                             7953318831018100268
# click_hash                                           NaN
# attributed                                         False
# implicit                                            True
# device_countrycode                   6333597102633388268
# device_brand                                 5.13799e+17
# device_model                                 6.02654e+18
# session_user_agent     HasOffers Mobile AppTracking v1.0
# user_agent                                           NaN
# event_uuid          0bfa9b4c-e07a-4522-b32d-138e3165ac98
# kind                                                Open
# wifi                                                 NaN
# trans_id                                             NaN
# ip_address                           4636407223847323867
# device_language                              3.30138e+18
#
#                                           3  \
# created             2019-03-13 04:20:57.698
# application_id                            0
# ref_type                1891515180541284343
# ref_hash                7953318831018100268
# click_hash                              NaN
# attributed                            False
# implicit                              False
# device_countrycode      6333597102633388268
# device_brand                    5.13799e+17
# device_model                    6.02654e+18
# session_user_agent                      NaN
# user_agent                              NaN
# event_uuid                              NaN
# kind                                    NaN
# wifi                                    NaN
# trans_id                                NaN
# ip_address              4636407223847323867
# device_language                         NaN
#
#                                                        4
# created                          2019-03-10 22:24:56.684
# application_id                                         0
# ref_type                             1891515180541284343
# ref_hash                             8355110941557237501
# click_hash                                           NaN
# attributed                                         False
# implicit                                            True
# device_countrycode                   6333597102633388268
# device_brand                                 1.08337e+18
# device_model                                 7.87661e+18
# session_user_agent     HasOffers Mobile AppTracking v1.0
# user_agent                                           NaN
# event_uuid          8f235a8c-41bf-4399-b33d-c41577c949b0
# kind                                                Open
# wifi                                                 NaN
# trans_id                                             NaN
# ip_address                            685400811232710215
# device_language                              3.30138e+18

# %%
len(installs)
# Out:
# 3412

# %%
installs.isnull().sum()
# Out:
# created                  0
# application_id           0
# ref_type                 0
# ref_hash                 0
# click_hash            3412
# attributed               0
# implicit                 0
# device_countrycode       0
# device_brand          2365
# device_model             1
# session_user_agent      48
# user_agent            1683
# event_uuid            2547
# kind                  2547
# wifi                  1683
# trans_id              3406
# ip_address               0
# device_language         34
# dtype: int64

# %%
len(installs)
# Out:
# 3412

# %%
installs['device_language'].value_counts()
# Out:
# 3.301378e+18    1484
# 9.028383e+18     714
# 4.621024e+18     632
# 6.977049e+18     238
# 4.077062e+17      70
# 1.526421e+18      56
# 4.060930e+18      48
# 2.822843e+17      39
# 6.035180e+18      24
# 1.193279e+18      21
# 6.535228e+18      10
# 1.101539e+17       9
# 3.177265e+18       5
# 3.695787e+17       5
# 3.095856e+18       4
# 6.569908e+18       2
# 5.846217e+18       2
# 7.774316e+18       2
# 4.594650e+18       2
# 6.782349e+18       1
# 5.061642e+18       1
# 1.686906e+18       1
# 5.794427e+17       1
# 2.488366e+18       1
# 3.544544e+18       1
# 3.074904e+18       1
# 2.061937e+18       1
# 4.073835e+18       1
# 6.846873e+18       1
# 7.045130e+18       1
# Name: device_language, dtype: int64

# %%
installs['ref_type'].value_counts()
# Out:
# 1891515180541284343    2080
# 1494519392962156891    1332
# Name: ref_type, dtype: int64

# %%
installs.loc[installs['device_model'].isnull()]
# Out:
#                       created  application_id             ref_type  \
# 2157  2019-03-09 16:08:19.919              30  1494519392962156891
#
#                  ref_hash  click_hash  attributed  implicit  \
# 2157  4364935818432173881         NaN       False      True
#
#        device_countrycode  device_brand  device_model  \
# 2157  6333597102633388268           NaN           NaN
#
#                      session_user_agent user_agent  \
# 2157  HasOffers Mobile AppTracking v1.0        NaN
#
#                                 event_uuid  kind wifi trans_id  \
# 2157  78082c4c-0fe1-4fc7-a718-4eba1d943b9c  Open  NaN      NaN
#
#                ip_address  device_language
# 2157  2208800741316080623              NaN

# %%
installs['session_user_agent'].value_counts()
# Out:
# http-kit/2.0                                                                                                                                                                                                                                                                  1729
# adjust.com                                                                                                                                                                                                                                                                    1592
# HasOffers Mobile AppTracking v1.0                                                                                                                                                                                                                                               22
# Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_4 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/12.0 Mobile/15E148 Safari/604.1                                                                                                                                       10
# Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) CriOS/72.0.3626.101 Mobile/15E148 Safari/605.1                                                                                                                                   3
# Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/12.0 Mobile/15E148 Safari/604.1                                                                                                                                        2
# Mozilla/5.0 (Linux; Android 6.0; ALE-L23) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.105 Mobile Safari/537.36                                                                                                                                                       1
# Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) GSA/68.0.234683655 Mobile/15E148 Safari/605.1                                                                                                                                    1
# Mozilla/5.0 (iPad; CPU OS 12_1_4 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/12.0 Mobile/15E148 Safari/604.1                                                                                                                                                 1
# Mozilla/5.0 (iPhone; CPU iPhone OS 11_2_6 like Mac OS X) AppleWebKit/604.5.6 (KHTML, like Gecko) Version/11.0 Mobile/15D100 Safari/604.1                                                                                                                                         1
# Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/16C101 [FBAN/FBIOS;FBAV/208.0.0.48.103;FBBV/141927594;FBDV/iPhone9,3;FBMD/iPhone;FBSN/iOS;FBSV/12.1.2;FBSS/2;FBCR/O2;FBID/phone;FBLC/en_GB;FBOP/5;FBRV/143280066]       1
# Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/11.0 Mobile/15E148 Safari/604.1                                                                                                                                        1
# Name: session_user_agent, dtype: int64

# %%
# grupos grandes, se puede pasar a un tipo diferente a int64 para que no ocupe tanta memoria
installs['application_id'].value_counts()
# Out:
# 7     947
# 9     731
# 10    389
# 16    362
# 8     328
# 2     174
# 29     97
# 20     95
# 6      35
# 1      34
# 26     28
# 34     28
# 15     20
# 0      18
# 3      17
# 28     17
# 12     15
# 18     14
# 24     13
# 17     13
# 14     13
# 21      7
# 5       3
# 13      3
# 33      2
# 30      2
# 19      2
# 32      2
# 36      1
# 4       1
# 23      1
# Name: application_id, dtype: int64

# %%
installs['application_id'] = installs['application_id'].astype(np.int8)

# %%
installs['ref_type'].value_counts()
# Out:
# 1891515180541284343    2080
# 1494519392962156891    1332
# Name: ref_type, dtype: int64

# %%
installs['attributed'].value_counts()
# Out:
# False    3412
# Name: attributed, dtype: int64

# %%
installs['trans_id'].value_counts()
# Out:
# {hash}                                  3
# 89bda305-bff1-4c22-ae23-1a237eac0002    1
# 44aeb6df-8db4-4b3f-ac67-0a802d479c86    1
# 22380348598                             1
# Name: trans_id, dtype: int64

# %%
installs.loc[installs['trans_id'].notnull()]
# Out:
#                       created  application_id             ref_type  \
# 2234  2019-03-09 19:48:10.457              16  1891515180541284343
# 3249  2019-03-12 13:00:45.072              16  1891515180541284343
# 3267  2019-03-12 22:27:58.098              16  1891515180541284343
# 3380  2019-03-06 17:01:26.123               1  1494519392962156891
# 3409  2019-03-05 11:03:58.537              19  1494519392962156891
# 3410  2019-03-07 13:42:47.814              19  1494519392962156891
#
#                  ref_hash  click_hash  attributed  implicit  \
# 2234  6173899971792625142         NaN       False     False
# 3249  6808608047290129862         NaN       False     False
# 3267  5517347051664000025         NaN       False     False
# 3380  5634738659911451938         NaN       False     False
# 3409  8280469812012804019         NaN       False     False
# 3410  1530864130516519187         NaN       False     False
#
#        device_countrycode  device_brand  device_model  \
# 2234  6333597102633388268  2.208835e+18  9.109466e+18
# 3249  6333597102633388268  2.208835e+18  8.716277e+18
# 3267  6333597102633388268  3.083059e+17  2.066431e+17
# 3380  6333597102633388268  5.951325e+18  8.354574e+18
# 3409  6333597102633388268  5.951325e+18  4.349816e+18
# 3410  6333597102633388268  5.951325e+18  1.764701e+18
#
#                                      session_user_agent  \
# 2234                                       http-kit/2.0
# 3249                                       http-kit/2.0
# 3267                                       http-kit/2.0
# 3380  Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like M...
# 3409  Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_4 like...
# 3410  Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like...
#
#                                              user_agent event_uuid kind  wifi  \
# 2234  Dalvik/2.1.0 (Linux; U; Android 7.1.1; Moto G ...        NaN  NaN  True
# 3249  Dalvik/2.1.0 (Linux; U; Android 7.0; Moto G (4...        NaN  NaN  True
# 3267  Dalvik/2.1.0 (Linux; U; Android 8.0.0; SM-G570...        NaN  NaN  True
# 3380                                                NaN        NaN  NaN   NaN
# 3409                                                NaN        NaN  NaN   NaN
# 3410                                                NaN        NaN  NaN   NaN
#
#                                   trans_id           ip_address  \
# 2234                                {hash}  6586849487961128061
# 3249                                {hash}  6799929828891198374
# 3267                                {hash}  3162368506662488065
# 3380  44aeb6df-8db4-4b3f-ac67-0a802d479c86  5145638343291847724
# 3409  89bda305-bff1-4c22-ae23-1a237eac0002   543629953276043235
# 3410                           22380348598  5929364725345188154
#
#       device_language
# 2234     9.028383e+18
# 3249     9.028383e+18
# 3267     9.028383e+18
# 3380     4.621024e+18
# 3409     4.621024e+18
# 3410     1.526421e+18

# %%
installs['kind'].value_counts()
# Out:
# af_app_opened                 428
# app_open                      212
# EVENT_Homepage                 70
# open                           36
# EVENT_OPEN_APP                 33
# Open                           22
# login_success                  17
# account_summary_first_step     13
# EVENT_HOMEPAGE                  6
# EVENT_LISTINGVIEW_FLIGHT        6
# deeplink                        5
# reattribution                   4
# payment method add              3
# registration                    3
# journey first drop off          2
# journey drop off                1
# EVENT_PROMO                     1
# journey reserved                1
# install                         1
# af_list_view                    1
# Name: kind, dtype: int64

# %%
#installs['contains_open'] = (installs['kind'] == 'open')
#installs['contains_open'].value_counts()

# %%
#installs['kind'].value_counts()
# Out:
# EVENT_HOMEPAGE    3412
# Name: kind, dtype: int64

# %%
#installs.loc[(installs['kind'] == 'Open') & (installs['kind'] == 'app_open') & \
#            installs['kind'] == 'open'] = 'EVENT_OPEN_APP'

# %%
installs['device_countrycode'].value_counts()
# Out:
# 6333597102633388268    1820
# 2970470518450881158    1592
# Name: device_countrycode, dtype: int64

# %%
#auctions['created'].str[:19]

# %%
pd.to_datetime(installs['created'], format='%Y-%m-%d %H:%M:%S').head()
# Out:
# 0   2019-03-13 01:43:33.445
# 1   2019-03-13 04:58:35.078
# 2   2019-03-13 04:20:57.666
# 3   2019-03-13 04:20:57.698
# 4   2019-03-10 22:24:56.684
# Name: created, dtype: datetime64[ns]

# %%
installs.groupby(['ref_type','device_countrycode']).agg('count')
# Out:
#                                          created  application_id  ref_hash  \
# ref_type            device_countrycode
# 1494519392962156891 2970470518450881158      487             487       487
#                     6333597102633388268      845             845       845
# 1891515180541284343 2970470518450881158     1105            1105      1105
#                     6333597102633388268      975             975       975
#
#                                          click_hash  attributed  implicit  \
# ref_type            device_countrycode
# 1494519392962156891 2970470518450881158           0         487       487
#                     6333597102633388268           0         845       845
# 1891515180541284343 2970470518450881158           0        1105      1105
#                     6333597102633388268           0         975       975
#
#                                          device_brand  device_model  \
# ref_type            device_countrycode
# 1494519392962156891 2970470518450881158             0           487
#                     6333597102633388268            72           844
# 1891515180541284343 2970470518450881158             0          1105
#                     6333597102633388268           975           975
#
#                                          session_user_agent  user_agent  \
# ref_type            device_countrycode
# 1494519392962156891 2970470518450881158                 487           0
#                     6333597102633388268                 805         772
# 1891515180541284343 2970470518450881158                1105           0
#                     6333597102633388268                 967         957
#
#                                          event_uuid  kind  wifi  trans_id  \
# ref_type            device_countrycode
# 1494519392962156891 2970470518450881158         146   146     0         0
#                     6333597102633388268         237   237   772         3
# 1891515180541284343 2970470518450881158         199   199     0         0
#                     6333597102633388268         283   283   957         3
#
#                                          ip_address  device_language  \
# ref_type            device_countrycode
# 1494519392962156891 2970470518450881158         487              487
#                     6333597102633388268         845              820
# 1891515180541284343 2970470518450881158        1105             1105
#                     6333597102633388268         975              966
#
#                                          contains_open
# ref_type            device_countrycode
# 1494519392962156891 2970470518450881158            487
#                     6333597102633388268            845
# 1891515180541284343 2970470518450881158           1105
#                     6333597102633388268            975

# %%
installs.groupby(['device_countrycode', 'session_user_agent']).agg('count')
# Out:
#                                                                         created  \
# device_countrycode  session_user_agent
# 2970470518450881158 adjust.com                                             1592
# 6333597102633388268 HasOffers Mobile AppTracking v1.0                        22
#                     Mozilla/5.0 (Linux; Android 6.0; ALE-L23) Apple...        1
#                     Mozilla/5.0 (iPad; CPU OS 12_1_4 like Mac OS X)...        1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_2_6 like ...        1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like ...        1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...        3
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...        1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...        1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...        2
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_4 like ...       10
#                     http-kit/2.0                                           1729
#
#                                                                         application_id  \
# device_countrycode  session_user_agent
# 2970470518450881158 adjust.com                                                    1592
# 6333597102633388268 HasOffers Mobile AppTracking v1.0                               22
#                     Mozilla/5.0 (Linux; Android 6.0; ALE-L23) Apple...               1
#                     Mozilla/5.0 (iPad; CPU OS 12_1_4 like Mac OS X)...               1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_2_6 like ...               1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like ...               1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...               3
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...               1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...               1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...               2
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_4 like ...              10
#                     http-kit/2.0                                                  1729
#
#                                                                         ref_type  \
# device_countrycode  session_user_agent
# 2970470518450881158 adjust.com                                              1592
# 6333597102633388268 HasOffers Mobile AppTracking v1.0                         22
#                     Mozilla/5.0 (Linux; Android 6.0; ALE-L23) Apple...         1
#                     Mozilla/5.0 (iPad; CPU OS 12_1_4 like Mac OS X)...         1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_2_6 like ...         1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like ...         1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...         3
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...         1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...         1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...         2
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_4 like ...        10
#                     http-kit/2.0                                            1729
#
#                                                                         ref_hash  \
# device_countrycode  session_user_agent
# 2970470518450881158 adjust.com                                              1592
# 6333597102633388268 HasOffers Mobile AppTracking v1.0                         22
#                     Mozilla/5.0 (Linux; Android 6.0; ALE-L23) Apple...         1
#                     Mozilla/5.0 (iPad; CPU OS 12_1_4 like Mac OS X)...         1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_2_6 like ...         1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like ...         1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...         3
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...         1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...         1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...         2
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_4 like ...        10
#                     http-kit/2.0                                            1729
#
#                                                                         click_hash  \
# device_countrycode  session_user_agent
# 2970470518450881158 adjust.com                                                   0
# 6333597102633388268 HasOffers Mobile AppTracking v1.0                            0
#                     Mozilla/5.0 (Linux; Android 6.0; ALE-L23) Apple...           0
#                     Mozilla/5.0 (iPad; CPU OS 12_1_4 like Mac OS X)...           0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_2_6 like ...           0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like ...           0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...           0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...           0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...           0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...           0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_4 like ...           0
#                     http-kit/2.0                                                 0
#
#                                                                         attributed  \
# device_countrycode  session_user_agent
# 2970470518450881158 adjust.com                                                1592
# 6333597102633388268 HasOffers Mobile AppTracking v1.0                           22
#                     Mozilla/5.0 (Linux; Android 6.0; ALE-L23) Apple...           1
#                     Mozilla/5.0 (iPad; CPU OS 12_1_4 like Mac OS X)...           1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_2_6 like ...           1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like ...           1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...           3
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...           1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...           1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...           2
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_4 like ...          10
#                     http-kit/2.0                                              1729
#
#                                                                         implicit  \
# device_countrycode  session_user_agent
# 2970470518450881158 adjust.com                                              1592
# 6333597102633388268 HasOffers Mobile AppTracking v1.0                         22
#                     Mozilla/5.0 (Linux; Android 6.0; ALE-L23) Apple...         1
#                     Mozilla/5.0 (iPad; CPU OS 12_1_4 like Mac OS X)...         1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_2_6 like ...         1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like ...         1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...         3
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...         1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...         1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...         2
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_4 like ...        10
#                     http-kit/2.0                                            1729
#
#                                                                         device_brand  \
# device_countrycode  session_user_agent
# 2970470518450881158 adjust.com                                                     0
# 6333597102633388268 HasOffers Mobile AppTracking v1.0                             21
#                     Mozilla/5.0 (Linux; Android 6.0; ALE-L23) Apple...             1
#                     Mozilla/5.0 (iPad; CPU OS 12_1_4 like Mac OS X)...             1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_2_6 like ...             1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like ...             1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...             3
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...             1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...             1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...             2
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_4 like ...            10
#                     http-kit/2.0                                                 957
#
#                                                                         device_model  \
# device_countrycode  session_user_agent
# 2970470518450881158 adjust.com                                                  1592
# 6333597102633388268 HasOffers Mobile AppTracking v1.0                             21
#                     Mozilla/5.0 (Linux; Android 6.0; ALE-L23) Apple...             1
#                     Mozilla/5.0 (iPad; CPU OS 12_1_4 like Mac OS X)...             1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_2_6 like ...             1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like ...             1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...             3
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...             1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...             1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...             2
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_4 like ...            10
#                     http-kit/2.0                                                1729
#
#                                                                         user_agent  \
# device_countrycode  session_user_agent
# 2970470518450881158 adjust.com                                                   0
# 6333597102633388268 HasOffers Mobile AppTracking v1.0                            0
#                     Mozilla/5.0 (Linux; Android 6.0; ALE-L23) Apple...           0
#                     Mozilla/5.0 (iPad; CPU OS 12_1_4 like Mac OS X)...           0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_2_6 like ...           0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like ...           0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...           0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...           0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...           0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...           0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_4 like ...           0
#                     http-kit/2.0                                              1729
#
#                                                                         event_uuid  \
# device_countrycode  session_user_agent
# 2970470518450881158 adjust.com                                                 345
# 6333597102633388268 HasOffers Mobile AppTracking v1.0                           22
#                     Mozilla/5.0 (Linux; Android 6.0; ALE-L23) Apple...           0
#                     Mozilla/5.0 (iPad; CPU OS 12_1_4 like Mac OS X)...           0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_2_6 like ...           0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like ...           0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...           0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...           0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...           0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...           0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_4 like ...           0
#                     http-kit/2.0                                               498
#
#                                                                         kind  \
# device_countrycode  session_user_agent
# 2970470518450881158 adjust.com                                           345
# 6333597102633388268 HasOffers Mobile AppTracking v1.0                     22
#                     Mozilla/5.0 (Linux; Android 6.0; ALE-L23) Apple...     0
#                     Mozilla/5.0 (iPad; CPU OS 12_1_4 like Mac OS X)...     0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_2_6 like ...     0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like ...     0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...     0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...     0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...     0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...     0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_4 like ...     0
#                     http-kit/2.0                                         498
#
#                                                                         wifi  \
# device_countrycode  session_user_agent
# 2970470518450881158 adjust.com                                             0
# 6333597102633388268 HasOffers Mobile AppTracking v1.0                      0
#                     Mozilla/5.0 (Linux; Android 6.0; ALE-L23) Apple...     0
#                     Mozilla/5.0 (iPad; CPU OS 12_1_4 like Mac OS X)...     0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_2_6 like ...     0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like ...     0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...     0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...     0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...     0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...     0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_4 like ...     0
#                     http-kit/2.0                                        1729
#
#                                                                         trans_id  \
# device_countrycode  session_user_agent
# 2970470518450881158 adjust.com                                                 0
# 6333597102633388268 HasOffers Mobile AppTracking v1.0                          0
#                     Mozilla/5.0 (Linux; Android 6.0; ALE-L23) Apple...         0
#                     Mozilla/5.0 (iPad; CPU OS 12_1_4 like Mac OS X)...         0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_2_6 like ...         0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like ...         0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...         0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...         1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...         1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...         0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_4 like ...         1
#                     http-kit/2.0                                               3
#
#                                                                         ip_address  \
# device_countrycode  session_user_agent
# 2970470518450881158 adjust.com                                                1592
# 6333597102633388268 HasOffers Mobile AppTracking v1.0                           22
#                     Mozilla/5.0 (Linux; Android 6.0; ALE-L23) Apple...           1
#                     Mozilla/5.0 (iPad; CPU OS 12_1_4 like Mac OS X)...           1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_2_6 like ...           1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like ...           1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...           3
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...           1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...           1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...           2
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_4 like ...          10
#                     http-kit/2.0                                              1729
#
#                                                                         device_language  \
# device_countrycode  session_user_agent
# 2970470518450881158 adjust.com                                                     1592
# 6333597102633388268 HasOffers Mobile AppTracking v1.0                                21
#                     Mozilla/5.0 (Linux; Android 6.0; ALE-L23) Apple...                0
#                     Mozilla/5.0 (iPad; CPU OS 12_1_4 like Mac OS X)...                1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_2_6 like ...                1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like ...                0
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...                3
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...                1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...                1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...                1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_4 like ...                7
#                     http-kit/2.0                                                   1729
#
#                                                                         contains_open
# device_countrycode  session_user_agent
# 2970470518450881158 adjust.com                                                   1592
# 6333597102633388268 HasOffers Mobile AppTracking v1.0                              22
#                     Mozilla/5.0 (Linux; Android 6.0; ALE-L23) Apple...              1
#                     Mozilla/5.0 (iPad; CPU OS 12_1_4 like Mac OS X)...              1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_2_6 like ...              1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like ...              1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...              3
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like Ma...              1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...              1
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like ...              2
#                     Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_4 like ...             10
#                     http-kit/2.0                                                 1729

# %%
#auctions.loc[auctions['application_id'] == 28].T #"Dalvik", tambien 2, 4, 10,14,16,28
installs.loc[installs['application_id'] == 15] # nextgen
#auctions.loc[auctions['application_id'] ==9] #mercadopago
#auctions.loc[auctions['application_id'] ==21] #peixelUrbano
#installs.loc[installs['application_id'] ==23] #takealot
#auctions.loc[auctions['application_id'] ==24] #hotelurbano
# Out:
#                       created  application_id             ref_type  \
# 914   2019-03-09 21:14:06.606              15  1494519392962156891
# 915   2019-03-09 18:15:44.732              15  1494519392962156891
# 916   2019-03-09 06:23:33.009              15  1494519392962156891
# 917   2019-03-09 13:26:56.049              15  1494519392962156891
# 918   2019-03-09 13:27:02.814              15  1494519392962156891
# 919   2019-03-10 22:41:40.742              15  1494519392962156891
# 920   2019-03-11 02:31:55.484              15  1494519392962156891
# 921   2019-03-12 00:06:57.917              15  1494519392962156891
# 922   2019-03-12 16:53:07.184              15  1494519392962156891
# 923   2019-03-12 02:26:55.794              15  1494519392962156891
# 2342  2019-03-06 03:46:16.024              15  1494519392962156891
# 2343  2019-03-06 23:30:49.084              15  1494519392962156891
# 2344  2019-03-07 00:10:05.928              15  1494519392962156891
# 2345  2019-03-07 03:11:03.946              15  1494519392962156891
# 2346  2019-03-07 21:01:43.749              15  1494519392962156891
# 2347  2019-03-07 18:19:22.370              15  1494519392962156891
# 2348  2019-03-07 14:22:28.087              15  1494519392962156891
# 2349  2019-03-08 21:29:49.712              15  1494519392962156891
# 2350  2019-03-08 18:47:54.051              15  1494519392962156891
# 2351  2019-03-08 01:12:55.091              15  1494519392962156891
#
#                  ref_hash  click_hash  attributed  implicit  \
# 914   8556062440603295870         NaN       False      True
# 915   6079287416243278322         NaN       False      True
# 916   1603040218690455718         NaN       False      True
# 917   7466801422498297667         NaN       False      True
# 918   5760731389761522845         NaN       False      True
# 919   1895191321305846352         NaN       False      True
# 920   4119276584717689563         NaN       False      True
# 921   7872111471026242552         NaN       False      True
# 922   8018359924032509209         NaN       False      True
# 923    465640578198795154         NaN       False      True
# 2342  1794379171561160164         NaN       False      True
# 2343  3761807832166367201         NaN       False      True
# 2344  1035121423954944546         NaN       False      True
# 2345  1083433359942757500         NaN       False      True
# 2346  1172950054920854224         NaN       False      True
# 2347   615364360344189222         NaN       False      True
# 2348  6422225600746478824         NaN       False      True
# 2349  3406096577260952933         NaN       False      True
# 2350  8288214953927629367         NaN       False      True
# 2351  3213386864209923261         NaN       False      True
#
#        device_countrycode  device_brand  device_model session_user_agent  \
# 914   6333597102633388268           NaN  2.331947e+18       http-kit/2.0
# 915   6333597102633388268           NaN  2.331947e+18       http-kit/2.0
# 916   6333597102633388268           NaN  2.331947e+18       http-kit/2.0
# 917   6333597102633388268           NaN  2.331947e+18       http-kit/2.0
# 918   6333597102633388268           NaN  2.331947e+18       http-kit/2.0
# 919   6333597102633388268           NaN  2.331947e+18       http-kit/2.0
# 920   6333597102633388268           NaN  2.331947e+18       http-kit/2.0
# 921   6333597102633388268           NaN  2.331947e+18       http-kit/2.0
# 922   6333597102633388268           NaN  2.331947e+18       http-kit/2.0
# 923   6333597102633388268           NaN  2.331947e+18       http-kit/2.0
# 2342  6333597102633388268           NaN  2.331947e+18       http-kit/2.0
# 2343  6333597102633388268           NaN  2.331947e+18       http-kit/2.0
# 2344  6333597102633388268           NaN  2.331947e+18       http-kit/2.0
# 2345  6333597102633388268           NaN  2.331947e+18       http-kit/2.0
# 2346  6333597102633388268           NaN  2.331947e+18       http-kit/2.0
# 2347  6333597102633388268           NaN  2.331947e+18       http-kit/2.0
# 2348  6333597102633388268           NaN  2.331947e+18       http-kit/2.0
# 2349  6333597102633388268           NaN  2.331947e+18       http-kit/2.0
# 2350  6333597102633388268           NaN  2.331947e+18       http-kit/2.0
# 2351  6333597102633388268           NaN  1.527930e+18       http-kit/2.0
#
#                                           user_agent  \
# 914         NextGen/1261 CFNetwork/976 Darwin/18.2.0
# 915         NextGen/1270 CFNetwork/976 Darwin/18.2.0
# 916         NextGen/1270 CFNetwork/976 Darwin/18.2.0
# 917         NextGen/1270 CFNetwork/976 Darwin/18.2.0
# 918     NextGen/1270 CFNetwork/975.0.3 Darwin/18.2.0
# 919         NextGen/1270 CFNetwork/976 Darwin/18.2.0
# 920         NextGen/1270 CFNetwork/976 Darwin/18.2.0
# 921         NextGen/1261 CFNetwork/976 Darwin/18.2.0
# 922         NextGen/1270 CFNetwork/976 Darwin/18.2.0
# 923         NextGen/1270 CFNetwork/976 Darwin/18.2.0
# 2342        NextGen/1261 CFNetwork/976 Darwin/18.2.0
# 2343        NextGen/1261 CFNetwork/976 Darwin/18.2.0
# 2344        NextGen/1261 CFNetwork/976 Darwin/18.2.0
# 2345        NextGen/1261 CFNetwork/976 Darwin/18.2.0
# 2346        NextGen/1270 CFNetwork/976 Darwin/18.2.0
# 2347        NextGen/1270 CFNetwork/976 Darwin/18.2.0
# 2348        NextGen/1204 CFNetwork/976 Darwin/18.2.0
# 2349    NextGen/1270 CFNetwork/811.5.4 Darwin/16.7.0
# 2350  NextGen/1230.4 CFNetwork/974.2.1 Darwin/18.0.0
# 2351        NextGen/1261 CFNetwork/976 Darwin/18.2.0
#
#                                 event_uuid           kind  wifi trans_id  \
# 914   4c9e6046-b5f1-4607-b891-9e995ef8dd3f  af_app_opened  True      NaN
# 915   f338f2fe-a762-4077-8f22-9e170874b6ad  af_app_opened  True      NaN
# 916   47bafd29-19e2-46f9-98a6-16ca6f58d55d  af_app_opened  True      NaN
# 917   7ea44180-096a-4851-972f-08c4d99d3956  af_app_opened  True      NaN
# 918   d8efd285-22db-46cb-9774-f567c8ea17ae  af_app_opened  True      NaN
# 919   288f4170-ac3d-499c-ba1c-d5d6e7f95da6  af_app_opened  True      NaN
# 920   502a8160-1176-4566-aa3c-134925a9e846  af_app_opened  True      NaN
# 921   6872b1e2-7102-4f8c-9284-b731398a7194  af_app_opened  True      NaN
# 922   a3a8a9aa-213e-4aaa-a8d1-64803842e0c8  af_app_opened  True      NaN
# 923   5636ed4c-ca61-4ce1-bc06-f5b5800affe2  af_app_opened  True      NaN
# 2342  be094c6f-a26c-42c6-8810-ec31ed801113  af_app_opened  True      NaN
# 2343  5c287780-686b-4f81-a0cf-2264f3ca4676  af_app_opened  True      NaN
# 2344  88dbe49a-873c-44ec-a92f-340a0b205da0  af_app_opened  True      NaN
# 2345  b01a7c97-70fa-4d6a-9079-475bc0ce6871  af_app_opened  True      NaN
# 2346  91dc1580-8008-4eab-8b34-a2d0be6a2a7a  af_app_opened  True      NaN
# 2347  c6dbc24b-97c0-4747-bdf0-537b44b5df78  af_app_opened  True      NaN
# 2348  f69cd353-82f5-4268-b550-a2009d351f1f  af_app_opened  True      NaN
# 2349  1ef167c7-7fca-4e27-b610-528a0461310f  af_app_opened  True      NaN
# 2350  61f1b9b7-123a-4bf2-8cdc-df961ac2aaa5  af_app_opened  True      NaN
# 2351  d0851486-4327-4d62-8eaf-48a946a3ba7e  af_app_opened  True      NaN
#
#                ip_address  device_language
# 914   7134390831866477633     5.846217e+18
# 915   8582101874976945662     2.822843e+17
# 916   1451644250326591920     4.594650e+18
# 917   1464494785927106750     2.822843e+17
# 918   5502843189994089353     2.822843e+17
# 919   1992632945768888579     2.822843e+17
# 920    190495585067379324     2.822843e+17
# 921   2762979799125352549     2.822843e+17
# 922   1004514703995266739     2.822843e+17
# 923    412503496336253962     2.822843e+17
# 2342  6870243718950382875     4.594650e+18
# 2343  1149067484856486736     1.101539e+17
# 2344   969228619669982108     2.822843e+17
# 2345  9221949873099483746     2.822843e+17
# 2346  6433919135498160239     6.846873e+18
# 2347  1429269890622145225     2.822843e+17
# 2348  1848801903392887974     2.822843e+17
# 2349  1798774855867913569     2.822843e+17
# 2350  2597761127428763065     2.822843e+17
# 2351  1717745431505217797     2.822843e+17

# %%
installs.loc[installs['application_id'] == 9]['kind'].value_counts() #mercado de pago tiene mas open que el resto
# Out:
# af_app_opened    196
# Name: kind, dtype: int64
